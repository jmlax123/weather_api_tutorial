# %%
baseurl = 'http://api.weatherapi.com/v1'
mickey_key = "PASTE_YOUR_KEY_HERE"

# %%
#http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
city = "Louisville"
baseurl = f'http://api.weatherapi.com/v1/current.json?key={mickey_key}&q={city}'
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1777481522,
#   'localtime': '2026-04-29 12:52'},
#  'current': {'last_updated_epoch': 1777481100,
#   'last_updated': '2026-04-29 12:45',
#   'temp_c': 14.4,
#   'temp_f': 57.9,
#   'is_day': 1,
#   'condition': {'text': 'Light rain',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#    'code': 1183},
#   'wind_mph': 8.9,
#   'wind_kph': 14.4,
#   'wind_degree': 312,
#   'wind_dir': 'NW',
#   'pressure_mb': 1012.0,
#   'pressure_in': 29.88,
#   'precip_mm': 0.46,
#   'precip_in': 0.02,
#   'humidity': 97,
#   'cloud': 100,
#   'feelslike_c': 13.4,
#   'feelslike_f': 56.1,
#   'windchill_c': 16.3,
#   'windchill_f': 61.4,
#   'heatindex_c': 16.3,
#   'heatindex_f': 61.4,
#   'dewpoint_c': 13.7,
#   'dewpoint_f': 56.7,
#   'vis_km': 6.4,
#   'vis_miles': 3.0,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (57.9, 97)

# %%
def get_weather(city):
    url = f'http://api.weatherapi.com/v1/current.json?key={mickey_key}&q={city}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f'Weather for {location['name']}, {location['region']}')
        print(f'Tempurature: {current['temp_f']}, °F / {current['temp_c']} °C')
        print(f'Condition: {current['condition']['text']}')
        print(f'Humidity: {current['humidity']}%')
        print(f'Wind Speed: {current['wind_mph']} mph')

    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Louisville")
# Out:
# Weather for Louisville, Kentucky
# Tempurature: 57.9, °F / 14.4 °C
# Condition: Light rain
# Humidity: 97%
# Wind Speed: 8.9 mph

# %%
get_weather("Lexington")
# Out:
# Weather for Lexington-Fayette, Kentucky
# Tempurature: 64.0, °F / 17.8 °C
# Condition: Overcast
# Humidity: 90%
# Wind Speed: 10.3 mph

# %%
get_weather(' louisville')
# Out:
# Weather for Louisville, Kentucky
# Tempurature: 57.9, °F / 14.4 °C
# Condition: Light rain
# Humidity: 97%
# Wind Speed: 8.9 mph

# %%
cities = ["Louisville", "Lexington", "Morehead", "New York"]
weather_data = []

for city in cities:
    url = f'http://api.weatherapi.com/v1/current.json?key={mickey_key}&q={city}'
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City": data['location']['name'],
            "Temperature": data['current']['temp_f'],
            "Condition": data['current']['condition']['text'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']
        })
    else:
        print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Louisville',
#   'Temperature': 57.9,
#   'Condition': 'Light rain',
#   'Humidity': 97,
#   'Wind Speed': 8.9},
#  {'City': 'Lexington-Fayette',
#   'Temperature': 64.0,
#   'Condition': 'Overcast',
#   'Humidity': 90,
#   'Wind Speed': 10.3},
#  {'City': 'Morehead',
#   'Temperature': 71.7,
#   'Condition': 'Mist',
#   'Humidity': 94,
#   'Wind Speed': 3.6},
#  {'City': 'New York',
#   'Temperature': 60.1,
#   'Condition': 'Overcast',
#   'Humidity': 47,
#   'Wind Speed': 10.5}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#                 City  Temperature   Condition  Humidity  Wind Speed
# 0         Louisville         57.9  Light rain        97         8.9
# 1  Lexington-Fayette         64.0    Overcast        90        10.3
# 2           Morehead         71.7        Mist        94         3.6
# 3           New York         60.1    Overcast        47        10.5

# %%
weather_df.to_csv("sample_weather_data.csv", index=False)
